# %%
# !pip uninstall ace -y
# Out:
# Found existing installation: ace 0.3.2
# Uninstalling ace-0.3.2:
#   Successfully uninstalled ace-0.3.2

# %%
from ace import ace

# %%
import pandas as pd
import numpy as np
#ignore warnings
import warnings
from etl_helper import * 
warnings.filterwarnings('ignore')

# Import the os module
import os

# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))

# Change the current working directory
#os.chdir('G:/My drive/NSW Offences/Scripts/')

# Print the current working directory
#print("Current working directory: {0}".format(os.getcwd()))

#import pipeline

#read connection credentials
#credentials=pd.read_excel("G:/My drive/NSW Offences/Scripts/connection.xlsx")

#query_string=""" SELECT * FROM prod."2021_census.gcp_all_juvenile_victims.lga"  """
#print(query_string)
#original_data = pipeline.do_query(query_string, credentials.user.iloc[0],credentials.password.iloc[0], credentials.host.iloc[0],credentials.port.iloc[0], credentials.database.iloc[0])
#original_data=pd.read_csv('https://data-lake-icmec-au.s3.ap-southeast-2.amazonaws.com/projectCrimeCensus/2021_census.gcp_all_juvenile_victims.lga.csv')


original_data =GetData(""" SELECT * FROM prod."2021_census.gcp_all_juvenile_victims.lga"  """)
original_data=original_data.set_index('index')
original_data.columns
original_data=original_data.T
#original_data.columns = original_data.iloc[0] 
#original_data=original_data[1:]
model_data=original_data.copy()
model_data
model_data=model_data.drop(['lga_code_2021'], axis=1)
model_data.head()
x=model_data.columns
x=pd.DataFrame(x)
x.to_csv('columns.csv')
model_data.columns

#divide the df into census and bocsar
len(model_data.columns)
bocsardata=model_data.iloc[:,-22:].copy()
censusdata=model_data.iloc[:,:len(model_data.columns)-22].copy()

#stats from data
# from pandas_profiling import ProfileReport
# profile = ProfileReport(bocsardata, title="Pandas Profiling Report")
# profile.to_file("data.html")

#censusdata.str.find('..')
#test = censusdata.select_dtypes([np.object]).apply(lambda x: x.str.contains('..').any())
#test
#select feature to be modelled
#target_feature='domestic_violence_related_assault.rate'
target_feature='domestic_violence_related_assault.count'
model_data=pd.concat([censusdata,bocsardata[[target_feature]]], axis=1)
model_data.columns
model_data.dtypes
censusdata.dtypes
censusdata.info()
#Do the correlation
corr_data=model_data.copy()
#corr_table=corr_data.corr()
# Out:
# Current working directory: /Users/icmec/Documents/ACE_Feature_importance
# <class 'pandas.core.frame.DataFrame'>
# Index: 128 entries, Albury to Yass Valley
# Columns: 16984 entries, g53b.f_accomfoods_cert to g60b.p_tot_tot
# dtypes: float64(16984)
# memory usage: 16.6+ MB

# %%
censusd
# Out:
# index              g53b.f_accomfoods_cert  g53b.f_accomfoods_id_ns  \
# Albury                              238.0                     16.0
# Armidale Regional                    98.0                      7.0
# Ballina                             206.0                     20.0
# Balranald                             6.0                      0.0
# Bathurst Regional                   138.0                     15.0
# ...                                   ...                      ...
# Wingecarribee                       192.0                     27.0
# Wollondilly                         130.0                     14.0
# Wollongong                          618.0                     60.0
# Woollahra                            47.0                     18.0
# Yass Valley                          50.0                      9.0
#
# index              g53b.f_accomfoods_tot  g53b.f_transpostwhse_pd  \
# Albury                             448.0                     13.0
# Armidale Regional                  179.0                      0.0
# Ballina                            417.0                      0.0
# Balranald                           14.0                      0.0
# Bathurst Regional                  275.0                      0.0
# ...                                  ...                      ...
# Wingecarribee                      462.0                      3.0
# Wollondilly                        228.0                      8.0
# Wollongong                        1424.0                     30.0
# Woollahra                          349.0                     28.0
# Yass Valley                         95.0                      0.0
#
# index              g53b.f_transpostwhse_gd_gc  g53b.f_transpostwhse_bd  \
# Albury                                    6.0                     25.0
# Armidale Regional                         0.0                      9.0
# Ballina                                   0.0                     17.0
# Balranald                                 0.0                      0.0
# Bathurst Regional                         0.0                     21.0
# ...                                       ...                      ...
# Wingecarribee                             5.0                     28.0
# Wollondilly                               0.0                     32.0
# Wollongong                               11.0                     84.0
# Woollahra                                 9.0                     95.0
# Yass Valley                               0.0                      6.0
#
# index              g53b.f_transpostwhse_add_d  g53b.f_transpostwhse_cert  \
# Albury                                   24.0                       62.0
# Armidale Regional                         3.0                       13.0
# Ballina                                  11.0                       34.0
# Balranald                                 0.0                        0.0
# Bathurst Regional                        24.0                       35.0
# ...                                       ...                        ...
# Wingecarribee                            22.0                       54.0
# Wollondilly                              45.0                      118.0
# Wollongong                              107.0                      251.0
# Woollahra                                20.0                       15.0
# Yass Valley                               9.0                        9.0
#
# index              g53b.f_transpostwhse_id_ns  g53b.f_transpostwhse_tot  ...  \
# Albury                                    5.0                     130.0  ...
# Armidale Regional                         0.0                      27.0  ...
# Ballina                                   3.0                      65.0  ...
# Balranald                                 0.0                       6.0  ...
# Bathurst Regional                         4.0                      93.0  ...
# ...                                       ...                       ...  ...
# Wingecarribee                            13.0                     128.0  ...
# Wollondilly                              11.0                     207.0  ...
# Wollongong                               22.0                     494.0  ...
# Woollahra                                 9.0                     177.0  ...
# Yass Valley                               3.0                      25.0  ...
#
# index              g60b.p_tot_managers  g60b.p_tot_professionals  \
# Albury                          3066.0                    5299.0
# Armidale Regional               1977.0                    3094.0
# Ballina                         2889.0                    4681.0
# Balranald                        238.0                      88.0
# Bathurst Regional               2471.0                    3898.0
# ...                                ...                       ...
# Wingecarribee                   3785.0                    5156.0
# Wollondilly                     3720.0                    3986.0
# Wollongong                     11323.0                   24620.0
# Woollahra                       7020.0                   12489.0
# Yass Valley                     1844.0                    1954.0
#
# index              g60b.p_tot_technictrades_w  g60b.p_tot_communpersnlsvc_w  \
# Albury                                 3853.0                        3634.0
# Armidale Regional                      1462.0                        1574.0
# Ballina                                2859.0                        2799.0
# Balranald                               107.0                         100.0
# Bathurst Regional                      2903.0                        3068.0
# ...                                       ...                           ...
# Wingecarribee                          3799.0                        2594.0
# Wollondilly                            4898.0                        2678.0
# Wollongong                            13766.0                       12667.0
# Woollahra                              1068.0                        1422.0
# Yass Valley                            1286.0                         982.0
#
# index              g60b.p_tot_clericaladminis_w  g60b.p_tot_sales_w  \
# Albury                                   3228.0              2462.0
# Armidale Regional                        1406.0              1034.0
# Ballina                                  2284.0              1999.0
# Balranald                                  99.0                54.0
# Bathurst Regional                        2426.0              1755.0
# ...                                         ...                 ...
# Wingecarribee                            2627.0              2009.0
# Wollondilly                              3812.0              2061.0
# Wollongong                              12282.0              7663.0
# Woollahra                                2861.0              1972.0
# Yass Valley                              1200.0               532.0
#
# index              g60b.p_tot_mach_oper_drivers  g60b.p_tot_labourers  \
# Albury                                   1779.0                2589.0
# Armidale Regional                         521.0                1499.0
# Ballina                                   858.0                2083.0
# Balranald                                 103.0                 165.0
# Bathurst Regional                        1376.0                2211.0
# ...                                         ...                   ...
# Wingecarribee                            1334.0                2265.0
# Wollondilly                              2411.0                2479.0
# Wollongong                               5962.0                8200.0
# Woollahra                                 196.0                 449.0
# Yass Valley                               361.0                 662.0
#
# index              g60b.p_tot_occu_id_ns  g60b.p_tot_tot
# Albury                             435.0         26344.0
# Armidale Regional                  202.0         12765.0
# Ballina                            316.0         20775.0
# Balranald                           21.0           973.0
# Bathurst Regional                  349.0         20457.0
# ...                                  ...             ...
# Wingecarribee                      397.0         23960.0
# Wollondilly                        493.0         26528.0
# Wollongong                        1524.0         98020.0
# Woollahra                          748.0         28230.0
# Yass Valley                        177.0          9001.0
#
# [128 rows x 16984 columns]

# %%
x, y = wang04.build_sample_ace_problem_wang04(N=200)

# %%
from ace.samples import wang04
x, y = wang04.build_sample_ace_problem_wang04(N=200)

from ace import model
myace = model.Model()
myace.build_model_from_xy(x, y)
myace.eval([0.1, 0.2, 0.5, 0.3, 0.5])
# Out:
# * Starting outer iteration 000. Current err =  1.00000E+00
#   Starting inner iteration 000. Current err =  1.00000E+00
#   Starting inner iteration 001. Current err =  4.69911E-02
#   Starting inner iteration 002. Current err =  2.25392E-02
#   Starting inner iteration 003. Current err =  2.10688E-02
#   Starting inner iteration 004. Current err =  2.07407E-02
#   Starting inner iteration 005. Current err =  2.04980E-02
# * Starting outer iteration 001. Current err =  1.05153E-02
#   Starting inner iteration 000. Current err =  1.05153E-02
#   Starting inner iteration 001. Current err =  7.77191E-03
#   Starting inner iteration 002. Current err =  7.28285E-03
#   Starting inner iteration 003. Current err =  7.17660E-03
#   Starting inner iteration 004. Current err =  7.17168E-03
#   Starting inner iteration 005. Current err =  7.16937E-03
#   Starting inner iteration 006. Current err =  7.16833E-03
#   Starting inner iteration 007. Current err =  7.16814E-03
#   Starting inner iteration 008. Current err =  7.16806E-03
#   Starting inner iteration 009. Current err =  7.16803E-03
#   Starting inner iteration 010. Current err =  7.16803E-03
#   Starting inner iteration 011. Current err =  7.16802E-03
#   Starting inner iteration 012. Current err =  7.16802E-03
#   Starting inner iteration 013. Current err =  7.16802E-03
#   Starting inner iteration 014. Current err =  7.16802E-03
#   Starting inner iteration 015. Current err =  7.16802E-03
#   Starting inner iteration 016. Current err =  7.16802E-03
#   Starting inner iteration 017. Current err =  7.16802E-03
#   Starting inner iteration 018. Current err =  7.16802E-03
#   Starting inner iteration 019. Current err =  7.16802E-03
#   Starting inner iteration 020. Current err =  7.16802E-03
#   Starting inner iteration 021. Current err =  7.16802E-03
#   Starting inner iteration 022. Current err =  7.16802E-03
#   Starting inner iteration 023. Current err =  7.16802E-03
# * Starting outer iteration 002. Current err =  6.49866E-03
#   Starting inner iteration 000. Current err =  6.49866E-03
# * Starting outer iteration 003. Current err =  6.44555E-03
#   Starting inner iteration 000. Current err =  6.44555E-03
# 1.6884076103714938

# %%
# from ace.samples import wang04
# xx, yy = wang04.build_sample_ace_problem_wang04(N=200)

myace = model.Model()
myace.build_model_from_xy(x.iloc[:3].to_numpy(), y.iloc[:3].to_numpy())
#myace.eval([0.1, 0.2, 0.5, 0.3, 0.5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [85], line 5
#       1 # from ace.samples import wang04
#       2 # xx, yy = wang04.build_sample_ace_problem_wang04(N=200)
#       4 myace = model.Model()
# ----> 5 myace.build_model_from_xy(x.iloc[:3].to_numpy(), y.iloc[:3].to_numpy())
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/model.py:70, in Model.build_model_from_xy(self, x_values, y_values)
#      68 """Construct the model and perform regressions based on x, y data."""
#      69 self.init_ace(x_values, y_values)
# ---> 70 self.run_ace()
#      71 self.build_interpolators()
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/model.py:79, in Model.run_ace(self)
#      77 def run_ace(self):
#      78     """Perform the ACE calculation."""
# ---> 79     self.ace.solve()
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/ace.py:67, in ACESolver.solve(self)
#      65 def solve(self):
#      66     """Run the ACE calculational loop."""
# ---> 67     self._initialize()
#      68     while self._outer_error_is_decreasing() and self._outer_iters < MAX_OUTERS:
#      69         print(('* Starting outer iteration {0:03d}. Current err = {1:12.5E}'
#      70               ''.format(self._outer_iters, self._last_outer_error)))
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/ace.py:80, in ACESolver._initialize(self)
#      78 self.y_transform /= numpy.std(self.y_transform)
#      79 self.x_transforms = [numpy.zeros(len(self.y)) for _xi in self.x]
# ---> 80 self._compute_sorted_indices()
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/ace.py:93, in ACESolver._compute_sorted_indices(self)
#      91 for to_sort in [self.y] + self.x:
#      92     data_w_indices = [(val, i) for (i, val) in enumerate(to_sort)]
# ---> 93     data_w_indices.sort()
#      94     sorted_indices.append([i for val, i in data_w_indices])
#      95 # save in meaningful variable names
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#####################################Here is the ACE algo
#I dont know why is this not working, the data seems correct
x=censusdata.fillna(0)
x=x.astype(float)
x=x.astype(int)
x.dtypes.to_excel("test.xlsx")
#https://github.com/partofthething/ace
#https://partofthething.com/ace/#using-it
#https://partofthething.com/ace/apidoc/ace.samples.html#module-ace.samples.breiman85

# from ace import ace
# censusdata.isnull().sum().sum()
# x=[*x.to_numpy()]#.fillna(0).values
# y=bocsardata[[target_feature]]
# ace_solver = ace.ACESolver()
# ace_solver.specify_data_set(x, [y])
# MAX_OUTERS = 200*1000
# ace_solver.solve()


from ace import ace
censusdata.isnull().sum().sum()
#x=[*x.to_numpy()]#.fillna(0).values
y=bocsardata[[target_feature]]
ace_solver = ace.ACESolver()
ace_solver.specify_data_set(x.iloc[:3].to_numpy(), yy[:3])
MAX_OUTERS = 200*1000
ace_solver.solve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [83], line 28
#      26 ace_solver.specify_data_set(x.iloc[:3].to_numpy(), yy[:3])
#      27 MAX_OUTERS = 200*1000
# ---> 28 ace_solver.solve()
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/ace.py:67, in ACESolver.solve(self)
#      65 def solve(self):
#      66     """Run the ACE calculational loop."""
# ---> 67     self._initialize()
#      68     while self._outer_error_is_decreasing() and self._outer_iters < MAX_OUTERS:
#      69         print(('* Starting outer iteration {0:03d}. Current err = {1:12.5E}'
#      70               ''.format(self._outer_iters, self._last_outer_error)))
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/ace.py:80, in ACESolver._initialize(self)
#      78 self.y_transform /= numpy.std(self.y_transform)
#      79 self.x_transforms = [numpy.zeros(len(self.y)) for _xi in self.x]
# ---> 80 self._compute_sorted_indices()
#
# File ~/Documents/PythonTests/ETLs/etl/lib/python3.9/site-packages/ace/ace.py:91, in ACESolver._compute_sorted_indices(self)
#      83 """
#      84 Sort data from the perspective of each column.
#      85
#    (...)
#      88 We only have to sort the data once.
#      89 """
#      90 sorted_indices = []
# ---> 91 for to_sort in [self.y] + self.x:
#      92     data_w_indices = [(val, i) for (i, val) in enumerate(to_sort)]
#      93     data_w_indices.sort()
#
# ValueError: operands could not be broadcast together with shapes (1,3) (3,16984)

# %%
###################################Here are some examples of the algo working

from ace import model
myace = model.Model()
myace.build_model_from_xy([x], y)
myace.eval([0.1, 0.2, 0.5, 0.3, 0.5])

from ace.samples import wang04
x, y = wang04.build_sample_ace_problem_wang04(N=200)
from ace import model
myace = model.Model()
myace.build_model_from_xy(x, y)
myace.eval([0.1, 0.2, 0.5, 0.3, 0.5])
from ace import ace
ace.plot_transforms(myace.ace, fname = 'mytransforms.pdf')
myace.ace.write_transforms_to_file(fname = 'mytransforms.txt')

import numpy
import numpy.random
import scipy.special
from .. import ace
numpy.random.seed(9287349087)

[docs]def build_sample_ace_problem_breiman85(N=200):
    """
    Sample problem from Breiman 1985
    """
    x3 = numpy.random.standard_normal(N)
    x = scipy.special.cbrt(x3)
    noise = numpy.random.standard_normal(N)
    y = numpy.exp((x ** 3.0) + noise)
    return [x], y


[docs]def run_breiman85():
    x, y = build_sample_ace_problem_breiman85(200)
    ace_solver = ace.ACESolver()
    ace_solver.specify_data_set(x, y)
    ace_solver.solve()
    try:
        ace.plot_transforms(ace_solver, 'sample_ace_breiman85.png')
    except ImportError:
        pass

    return ace_solver

if __name__ == '__main__':
    run_breiman85()
