# %%
# AWS Glue Studio Notebook
#### Packages

# %%
#!pip install pyspark --upgrade
from pyspark.sql.functions import *
from awsglue.dynamicframe import DynamicFrame

# %%
# %idle_timeout 2880
# %glue_version 3.0
# %worker_type G.1X
# %number_of_workers 2

import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

#custom added function
from datetime import date
from pyspark.sql.functions import lit
  
sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)
# Out:
# Welcome to the Glue Interactive Sessions Kernel
# For more information on available magic commands, please type %help in any new cell.
#
# Please view our Getting Started page to access the most up-to-date information on the Interactive Sessions kernel: https://docs.aws.amazon.com/glue/latest/dg/interactive-sessions.html
# Installed kernel version: 0.37.0
# Current idle_timeout is 2800 minutes.
# idle_timeout has been set to 2880 minutes.
# Setting Glue version to: 3.0
# Previous worker type: G.1X
# Setting new worker type to: G.1X
# Previous number of workers: 5
# Setting new number of workers to: 2
# Authenticating with environment variables and user-defined glue_role_arn: arn:aws:iam::702434652276:role/AWSGlueServiceRole-Studio
# Trying to create a Glue session for the kernel.
# Worker Type: G.1X
# Number of Workers: 2
# Session ID: 4efd998b-a8ea-4a75-8f75-f464d72afada
# Job Type: glueetl
# Applying the following default arguments:
# --glue_kernel_version 0.37.0
# --enable-glue-datacatalog true
# Waiting for session 4efd998b-a8ea-4a75-8f75-f464d72afada to get into ready status...
# Session 4efd998b-a8ea-4a75-8f75-f464d72afada has been created.

# %% [markdown]
# #### extract  data from s3

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 3.1.1+amzn.0

# %%
# Get the current date as a string
current_date_str = date.today().strftime('%d-%m-%Y')

# Print the date string
print(current_date_str)

current_date_str = "27-04-2023"
print(current_date_str)
# Out:
# 28-04-2023
# 27-04-2023

# %%
chatDynamicFrame = glueContext.create_dynamic_frame.from_options(
    connection_type="s3",
    connection_options={"paths": [f"s3://landing-zone-crc/chat/{current_date_str}.csv"]},
    format="csv",
    format_options={
        "withHeader": True,
    },
)
chatDf = chatDynamicFrame.toDF()

# %%
p2pDynamicFrame = glueContext.create_dynamic_frame.from_options(
    connection_type="s3",
    connection_options={"paths": [f"s3://landing-zone-crc/p2p/{current_date_str}.csv"]},
    format="csv",
    format_options={
        "withHeader": True,
    },
)
p2pDf = p2pDynamicFrame.toDF()

# %%
ipsDynamicFrame = glueContext.create_dynamic_frame.from_options(
    connection_type="s3",
    connection_options={"paths": [f"s3://landing-zone-crc/ips/{current_date_str}.csv"]},
    format="csv",
    format_options={
        "withHeader": True,
    },
)
ipsDf = ipsDynamicFrame.toDF()

# %%
#p2pDf.show()
# Out:
# +---------+--------------+----------+----+--------------------+------------+----------+-------+------+----------------+----------------+---------------------+
# |IPAddress|     Timestamp|SourceType|Port|                GUID|      Vendor|  UserName|Country|Region|             ISP|             Org|CategorizedAsExplicit|
# +---------+--------------+----------+----+--------------------+------------+----------+-------+------+----------------+----------------+---------------------+
# |  1.2.3.4|1/01/2023 0:00|         G|6346|12345EC22866504F8...|eMule v0.60d|Superdad38|     AU|     2|Telstra Internet|Telstra Internet|                    1|
# |  1.2.3.6|1/01/2023 0:00|         G|6346|12345EC22866504F8...|eMule v0.60d|Superdad38|     AU|     2| AussieBroadband| AussieBroadband|                    1|
# +---------+--------------+----------+----+--------------------+------------+----------+-------+------+----------------+----------------+---------------------+

# %% [markdown]
# #### Transformations

# %%
chatDf = chatDf.withColumn( 'chat' , lit(1) )

# %%
merged_df = chatDf.unionByName(p2pDf, allowMissingColumns=True)

# %%
merged_df = merged_df.join(ipsDf,merged_df.IPAddress ==  ipsDf.IPAddress,"left").drop(ipsDf.IPAddress)

# %%
#merged_df.show()
# Out:
# +---------+--------------+---------+----------+-----------+--------+-------+-------+------+----------------+----------------+----+----------+----+----+------+---------------------+-----+
# |     Date|     Timestamp|IPAddress|    UserID|   UserName| Network|Channel|Country|Region|             ISP|             Org|chat|SourceType|Port|GUID|Vendor|CategorizedAsExplicit|Label|
# +---------+--------------+---------+----------+-----------+--------+-------+-------+------+----------------+----------------+----+----------+----+----+------+---------------------+-----+
# |1/01/2023|1/01/2023 0:00|  1.2.3.4|Superdad38|~superdad38|undernet|#incest|     AU|     2|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null|    A|
# |4/01/2023|4/01/2023 0:00| 1.2.3.25|Superdad59|~superdad59|undernet|#incest|     AU|    23|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |6/01/2023|6/01/2023 0:00| 1.2.3.28|Superdad62|~superdad62|undernet|#incest|     AU|    26|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00|  1.2.3.8|Superdad42|~superdad41|undernet|   #abc|     AU|     6|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00|  1.2.3.9|Superdad43|~superdad43|undernet|#incest|     AU|     7|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00| 1.2.3.13|Superdad47|~superdad47|undernet|#incest|     FR|    11|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |3/01/2023|3/01/2023 0:00| 1.2.3.19|Superdad53|~superdad53|undernet|#incest|     FR|    17|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |4/01/2023|4/01/2023 0:00| 1.2.3.23|Superdad57|~superdad57|undernet|#incest|     AU|    21|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00|  1.2.3.7|Superdad41|~superdad41|undernet|#incest|     AU|     5|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00| 1.2.3.10|Superdad44|~superdad43|undernet|  #play|     AU|     8|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00| 1.2.3.11|Superdad45|~superdad45|undernet|#incest|     AU|     9|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00| 1.2.3.14|Superdad48|~superdad48|undernet|#incest|     AU|    12|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00| 1.2.3.16|Superdad50|~superdad50|undernet|#incest|     AU|    14|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |2/01/2023|2/01/2023 0:00| 1.2.3.17|Superdad51|~superdad51|undernet|#incest|     AU|    15|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |3/01/2023|3/01/2023 0:00| 1.2.3.18|Superdad52|~superdad52|undernet|#incest|     AU|    16|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |3/01/2023|3/01/2023 0:00| 1.2.3.20|Superdad54|~superdad54|undernet|#incest|     FR|    18|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |4/01/2023|4/01/2023 0:00| 1.2.3.22|Superdad56|~superdad56|undernet|#incest|     AU|    20|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |4/01/2023|4/01/2023 0:00| 1.2.3.24|Superdad58|~superdad58|undernet|#incest|     AU|    22|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |5/01/2023|5/01/2023 0:00| 1.2.3.26|Superdad60|~superdad60|undernet|#incest|     FR|    24|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# |5/01/2023|5/01/2023 0:00| 1.2.3.27|Superdad61|~superdad61|undernet|#incest|     FR|    25|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null| null|
# +---------+--------------+---------+----------+-----------+--------+-------+-------+------+----------------+----------------+----+----------+----+----+------+---------------------+-----+
# only showing top 20 rows

# %%
merged_df = merged_df.withColumn("date_column", to_date(split(col("Timestamp"), " ")[0], "d/MM/yyyy") )

#merged_df.printSchema()

# %%
merged_df = merged_df.withColumn("year", year("date_column"))
merged_df = merged_df.withColumn("month", month("date_column"))
merged_df = merged_df.withColumn("day", dayofmonth("date_column"))
#merged_df.show(1)

# %%
#merged_df.show(1)
# Out:
# +---------+--------------+---------+----------+-----------+--------+-------+-------+------+----------------+----------------+----+----------+----+----+------+---------------------+-----+-----------+----+-----+---+
# |     Date|     Timestamp|IPAddress|    UserID|   UserName| Network|Channel|Country|Region|             ISP|             Org|chat|SourceType|Port|GUID|Vendor|CategorizedAsExplicit|Label|date_column|year|month|day|
# +---------+--------------+---------+----------+-----------+--------+-------+-------+------+----------------+----------------+----+----------+----+----+------+---------------------+-----+-----------+----+-----+---+
# |1/01/2023|1/01/2023 0:00|  1.2.3.4|Superdad38|~superdad38|undernet|#incest|     AU|     2|Telstra Internet|Telstra Internet|   1|      null|null|null|  null|                 null|    A| 2023-01-01|2023|    1|  1|
# +---------+--------------+---------+----------+-----------+--------+-------+-------+------+----------------+----------------+----+----------+----+----+------+---------------------+-----+-----------+----+-----+---+
# only showing top 1 row

# %%
merged_df.write.partitionBy("year", "month", "day").mode("overwrite").parquet("s3://transformed-zone-crc/test/")

# %% [markdown]
# #### Example: Write the data in the DynamicFrame to a location in Amazon S3 and a table for it in the AWS Glue Data Catalog

# %%
# s3output = glueContext.getSink(
#   path="s3://bucket_name/folder_name",
#   connection_type="s3",
#   updateBehavior="UPDATE_IN_DATABASE",
#   partitionKeys=[],
#   compression="snappy",
#   enableUpdateCatalog=True,
#   transformation_ctx="s3output",
# )
# s3output.setCatalogInfo(
#   catalogDatabase="demo", catalogTableName="populations"
# )
# s3output.setFormat("glueparquet")
# s3output.writeFrame(DyF)
